# %% [markdown]
# <a href="https://colab.research.google.com/github/atyant20039/RL-Project-MCAC/blob/master/MCAC_Pointmass_Navigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment Setup

# %%
# !git clone https://github.com/atyant20039/RL-Project-MCAC.git
# Out:
# Cloning into 'RL-Project-MCAC'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 49 (delta 7), reused 49 (delta 7), pack-reused 0
# Receiving objects: 100% (49/49), 2.71 MiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd RL-Project-MCAC
# Out:
# /content/RL-Project-MCAC

# %%
# !pip install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 29.5 MB/s eta 0:00:00
# ...

# %%
# !virtualenv venv
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 794ms
#   creator CPython3Posix(dest=/content/RL-Project-MCAC/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.3.1, setuptools==69.0.2, wheel==0.42.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source venv/bin/activate

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/RL-Project-MCAC
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.9 MB/s eta 0:00:00
# ...
#   Running setup.py develop for mcac
# ...

# %% [markdown]
# # SAC Algorithm

# %%
# !python scripts/train.py --algo sac --env navigation --n-demos 20 --tau 0.05 --init-iters 500 --gen-data
# Out:
# Streaming output truncated to the last 5000 lines.
# |      StdTestEpRet |           0.458 |
# |         TestEpLen |            54.3 |
# | AverageTrainEpRet |           -61.7 |
# |     StdTrainEpRet |            2.42 |
# |        TrainEpLen |            62.7 |
# |                Q1 |           -41.5 |
# |                Q2 |           -41.5 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |             617 |
# | TotalEnvInteracts |        6.17e+05 |
# |  AverageTestEpRet |           -53.4 |
# |      StdTestEpRet |            0.49 |
# |         TestEpLen |            54.4 |
# | AverageTrainEpRet |           -61.4 |
# |     StdTrainEpRet |            2.76 |
# |        TrainEpLen |            62.4 |
# |                Q1 |           -41.3 |
# |                Q2 |           -41.3 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# ...

# %%
# !python scripts/train.py --algo sac --env navigation --n-demos 20 --tau 0.05 --init-iters 500 --do-mcac-bonus --gen-data
# Out:
# Streaming output truncated to the last 5000 lines.
# |  AverageTestEpRet |            -100 |
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |            -100 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |             100 |
# |                Q1 |             115 |
# |                Q2 |             115 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |             617 |
# | TotalEnvInteracts |        6.17e+05 |
# |  AverageTestEpRet |            -100 |
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |            -100 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |             100 |
# |                Q1 |             109 |
# |                Q2 |             109 |
# ---------------------------------------
# Testing Agent
# ...

# %% [markdown]
# # TD3 Algorithm

# %%
# !python scripts/train.py --algo td3 --env navigation --n-demos 20 --init-iters 500 --tau 0.05 --gen-data
# Out:
# Streaming output truncated to the last 5000 lines.
# |      StdTestEpRet |           0.458 |
# |         TestEpLen |            28.3 |
# | AverageTrainEpRet |            -130 |
# |     StdTrainEpRet |            1.63 |
# |        TrainEpLen |            30.8 |
# |                Q1 |            -102 |
# |                Q2 |            -102 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |             617 |
# | TotalEnvInteracts |        6.17e+05 |
# |  AverageTestEpRet |            -134 |
# |      StdTestEpRet |           0.671 |
# |         TestEpLen |            35.5 |
# | AverageTrainEpRet |            -131 |
# |     StdTrainEpRet |            2.27 |
# |        TrainEpLen |            31.8 |
# |                Q1 |            -101 |
# |                Q2 |            -101 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# ...

# %%
# !python scripts/train.py --algo td3 --env navigation --n-demos 20 --init-iters 500 --tau 0.05 --do-mcac-bonus --gen-data
# Out:
# Streaming output truncated to the last 5000 lines.
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |            -100 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |             100 |
# |                Q1 |           -32.9 |
# |                Q2 |           -32.9 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |             617 |
# | TotalEnvInteracts |        6.17e+05 |
# |  AverageTestEpRet |            -100 |
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |            -102 |
# |     StdTrainEpRet |            7.19 |
# |        TrainEpLen |            93.3 |
# |                Q1 |           -32.8 |
# |                Q2 |           -32.8 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# ...

# %% [markdown]
# # GQE Algorithm

# %%
# !python scripts/train.py --algo gqe --env navigation --n-demos 20 --tau 0.05 --total-timesteps 150000 --gqe --gqe-lambda 0.9 --init-iters 500 --gen-data
# Out:
# /content/RL-Project-MCAC/mcac/algos/core.py:315: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if special_policy is 'awac':
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-12/21-45-25/progress.csv
# ...
# Pretraining Policy
# 100% 500/500 [00:09<00:00, 55.10it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |            -100 |
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ...

# %%
# !python scripts/train.py --algo gqe --env navigation --n-demos 20 --tau 0.05 --total-timesteps 150000 --gqe --gqe-lambda 0.9 --do-mcac-bonus --gen-data --init-iters 500
# Out:
# /content/RL-Project-MCAC/mcac/algos/core.py:315: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if special_policy is 'awac':
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-12/22-05-47/progress.csv
# ...
# Pretraining Policy
# 100% 500/500 [00:09<00:00, 50.18it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |            -100 |
# |      StdTestEpRet |               0 |
# |         TestEpLen |             100 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ...

# %% [markdown]
# # AWAC Algorithm

# %%
# !python scripts/train.py --algo awac --env navigation --n-demos 17 --update-n-steps 50 --num-eval-episodes 10 --init-iters 500 --gen-data
# Out:
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-12/22-52-25/progress.csv
# Data already exists. Type `o` to overwrite, type anything else to skip data collection... > o
# ...
# Pretraining Policy
# 100% 500/500 [00:05<00:00, 86.79it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |           -90.6 |
# |      StdTestEpRet |            35.2 |
# |         TestEpLen |            41.5 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ---------------------------------------
# Testing Agent
# ...

# %%
# !python scripts/train.py --algo awac --env navigation --n-demos 20 --update-n-steps 50 --num-eval-episodes 10 --init-iters 500 --do-mcac-bonus --gen-data
# Out:
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-12/22-53-48/progress.csv
# Data already exists. Type `o` to overwrite, type anything else to skip data collection... > o
# ...
# Pretraining Policy
# 100% 500/500 [00:05<00:00, 89.31it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |           -54.5 |
# |      StdTestEpRet |            22.2 |
# |         TestEpLen |            45.5 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ---------------------------------------
# Testing Agent
# ...

# %% [markdown]
# # CQL Algorithm

# %%
# !python scripts/train.py --algo cql --env navigation --n-demos 20 --init-iters 500 --num-eval-episodes 5
# Out:
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-13/00-04-11/progress.csv
# Pretraining Policy
# 100% 500/500 [00:10<00:00, 46.14it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |            -124 |
# |      StdTestEpRet |             0.4 |
# |         TestEpLen |            24.8 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |               1 |
# ...

# %%
# !python scripts/train.py --algo cql --env navigation --n-demos 20 --init-iters 500 --num-eval-episodes 5 --do-mcac-bonus
# Out:
# Using cuda:0
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Logging data to outputs/2023-12-13/00-05-36/progress.csv
# Pretraining Policy
# 100% 500/500 [00:13<00:00, 38.19it/s]
# Testing Agent
# ---------------------------------------
# |             Epoch |               0 |
# | TotalEnvInteracts |               0 |
# |  AverageTestEpRet |            -123 |
# |      StdTestEpRet |             0.4 |
# |         TestEpLen |            24.2 |
# | AverageTrainEpRet |               0 |
# |     StdTrainEpRet |               0 |
# |        TrainEpLen |               0 |
# |                Q1 |               0 |
# |                Q2 |               0 |
# ---------------------------------------
# Testing Agent
# ---------------------------------------
# |             Epoch |               1 |
# ...
